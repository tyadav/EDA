# %%
# Pandas useful tips for easy data exploration 
import pandas as pd

# %%
#iris = sns.load_dataset('iris')
#iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df = pd.read_csv('C:\\Datasets-master\\dataset_nobel_laureate.csv')

# %%
# To get complete information about the data/dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  921 non-null    float64
#  1   Category              921 non-null    object
#  2   Prize                 911 non-null    object
#  3   Motivation            823 non-null    object
#  4   Prize Share           911 non-null    object
#  5   Laureate ID           911 non-null    float64
#  6   Laureate Type         921 non-null    object
#  7   Full Name             921 non-null    object
#  8   Birth Date            964 non-null    object
#  9   Birth Year            960 non-null    object
#  10  Age                   615 non-null    float64
#  11  Birth City            941 non-null    object
#  12  Birth Country         943 non-null    object
#  13  Sex                   943 non-null    object
#  14  Organization Name     722 non-null    object
# ...

# %%
# To get number of rows quickly
len(df)
# Out:
# 979

# %%
# And to get all the column names
df.columns
# Out:
# Index(['Year', 'Category', 'Prize', 'Motivation', 'Prize Share', 'Laureate ID',
#        'Laureate Type', 'Full Name', 'Birth Date', 'Birth Year', 'Age',
#        'Birth City', 'Birth Country', 'Sex', 'Organization Name',
#        'Organization City', 'Organization Country', 'Death Date', 'Death Year',
#        'Death City', 'Death Country'],
#       dtype='object')

# %%
# But if you want to check the number of columns
len(df.columns)
# Out:
# 21

# %%
# to check dataset statistics

df.describe()
# Out:
#               Year  Laureate ID         Age   Death Year
# count   921.000000   911.000000  615.000000   617.000000
# mean   1969.720955   462.515917   81.860163  1978.711507
# std      33.032943   270.236159   10.437808    39.059035
# min    1901.000000     1.000000   39.000000  1595.000000
# 25%    1946.000000   228.500000   75.000000  1958.000000
# 50%    1975.000000   457.000000   83.000000  1984.000000
# 75%    1998.000000   698.500000   90.000000  2003.000000
# max    2017.000000   937.000000  103.000000  2460.000000

# %%
# to get top 5 rows
df.head()

# or we can mention the number of rows want to see
# df.head(20)  for Top 10 rows

# and to check the last 5 rows
# df.tail()
# Out:
#      Year    Category                                           Prize  \
# 0  1901.0   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901.0  Literature              The Nobel Prize in Literature 1901
# 2  1901.0    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901.0       Peace                      The Nobel Peace Prize 1901
# 4  1901.0       Peace                      The Nobel Peace Prize 1901
#
#                                                                                   Motivation  \
# 0  "in recognition of the extraordinary services he has rendered by the discovery of the ...
# 1  "in special recognition of his poetic composition, which gives evidence of lofty ideal...
# 2  "for his work on serum therapy, especially its application against diphtheria, by whic...
# 3                                                                                        NaN
# ...

# %%
# to get every 10th record of a dataframe

every_10 = df[::10]
every_10.head()
# Out:
#       Year   Category                              Prize  \
# 0   1901.0  Chemistry  The Nobel Prize in Chemistry 1901
# 10  1902.0      Peace         The Nobel Peace Prize 1902
# 20  1904.0  Chemistry  The Nobel Prize in Chemistry 1904
# 30  1905.0    Physics    The Nobel Prize in Physics 1905
# 40  1907.0      Peace         The Nobel Peace Prize 1907
#
#                                                                                    Motivation  \
# 0   "in recognition of the extraordinary services he has rendered by the discovery of the ...
# 10                                                                                        NaN
# 20  "in recognition of his services in the discovery of the inert gaseous elements in air,...
# 30                                                             "for his work on cathode rays"
# 40                                                                                        NaN
#
# ...

# %%
# to get a particular item from a DataFrame

df.iat[3,4]
# Out:
# '01-Feb'

# %%
# another way to get a particualr item from dataframe

df.at[10,'Laureate ID']
# Out:
# 465.0

# %%
df.at[2,'Motivation']
# Out:
# '"for his work on serum therapy, especially its application against diphtheria, by which he has opened a new road in the domain of medical science and thereby placed in the hands of the physician a victorious weapon against illness and deaths"'

# %%
# To filter rows from a dataframe for single row instance

df1 = df[df['Birth Country'] == 'Switzerland']

# %%
df1.tail()
# Out:
#        Year   Category                                                  Prize  \
# 600  1989.0    Physics                        The Nobel Prize in Physics 1989
# 635  1993.0      Peace                             The Nobel Peace Prize 1993
# 692  1998.0   Medicine         The Nobel Prize in Physiology or Medicine 1998
# 761  2004.0  Economics  The Sveriges Riksbank Prize in Economic Sciences 2004
# 762  2004.0  Economics  The Sveriges Riksbank Prize in Economic Sciences 2004
#
#                                                                                     Motivation  \
# 600                                            "for the development of the ion trap technique"
# 635  "for their work for the peaceful termination of the apartheid regime, and for laying t...
# 692  "for their discoveries concerning nitric oxide as a signalling molecule in the cardiov...
# 761  "for their contributions to dynamic macroeconomics: the time consistency of economic p...
# ...

# %%
# To filter multiple row instances from particular column

df2 = df[df['Category'].isin(['Peace', 'Medicine', 'Economics'])]

# %%
df2.head()
# Out:
#      Year  Category                                           Prize  \
# 2  1901.0  Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901.0     Peace                      The Nobel Peace Prize 1901
# 4  1901.0     Peace                      The Nobel Peace Prize 1901
# 8  1902.0  Medicine  The Nobel Prize in Physiology or Medicine 1902
# 9  1902.0     Peace                      The Nobel Peace Prize 1902
#
#                                                                                   Motivation  \
# 2  "for his work on serum therapy, especially its application against diphtheria, by whic...
# 3                                                                                        NaN
# 4                                                                                        NaN
# 8  "for his work on malaria, by which he has shown how it enters the organism and thereby...
# 9                                                                                        NaN
#
# ...

# %%
# To get sum of values of a dataframe
df.sum()
# Out:
# Year           1814113.0
# Laureate ID     421352.0
# Age              50344.0
# Death Year     1220865.0
# dtype: float64

# %%
# to get lowest values of a dataframe

df.min()
# Out:
# Year           1901.0
# Laureate ID       1.0
# Age              39.0
# Death Year     1595.0
# dtype: float64

# %%
# to get highest value of a dataframe
df.max()
# Out:
# Year           2017.0
# Laureate ID     937.0
# Age             103.0
# Death Year     2460.0
# dtype: float64

# %%
# to get average value of a dataframe

df.mean()
# Out:
# Year           1969.720955
# Laureate ID     462.515917
# Age              81.860163
# Death Year     1978.711507
# dtype: float64

# %%
# To get median values

df.median()
# Out:
# Year           1975.0
# Laureate ID     457.0
# Age              83.0
# Death Year     1984.0
# dtype: float64

# %%
# to get a unique entries of a column

df3 = df(['Laureate ID','size'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-a9bb3d7837ba> in <module>
#       1 # to get a unique entries of a column
#       2
# ----> 3 df3 = df(['Laureate ID','size'])
#
# TypeError: 'DataFrame' object is not callable

# %%
df.columns
# Out:
# Index(['Year', 'Category', 'Prize', 'Motivation', 'Prize Share', 'Laureate ID',
#        'Laureate Type', 'Full Name', 'Birth Date', 'Birth Year', 'Age',
#        'Birth City', 'Birth Country', 'Sex', 'Organization Name',
#        'Organization City', 'Organization Country', 'Death Date', 'Death Year',
#        'Death City', 'Death Country'],
#       dtype='object')

# %%
# To get corelation between columns
df.corr()
# Out:
#                  Year  Laureate ID       Age  Death Year
# Year         1.000000     0.579784  0.171547    0.699629
# Laureate ID  0.579784     1.000000  0.077974    0.220071
# Age          0.171547     0.077974  1.000000    0.360688
# Death Year   0.699629     0.220071  0.360688    1.000000

# %%
# To sort dataframe

df.sort_values(by=['Category'], ascending = False)
# Out:
#        Year Category                            Prize  \
# 460  1975.0  Physics  The Nobel Prize in Physics 1975
# 314  1958.0  Physics  The Nobel Prize in Physics 1958
# 312  1958.0  Physics  The Nobel Prize in Physics 1958
# 744  2002.0  Physics  The Nobel Prize in Physics 2002
# 305  1957.0  Physics  The Nobel Prize in Physics 1957
# ..      ...      ...                              ...
# 974     NaN      NaN                              NaN
# 975     NaN      NaN                              NaN
# 976     NaN      NaN                              NaN
# 977     NaN      NaN                              NaN
# 978     NaN      NaN                              NaN
#
#                                                                                     Motivation  \
# 460  "for the discovery of the connection between collective motion and particle motion in ...
# 314                         "for the discovery and the interpretation of the Cherenkov effect"
# ...

# %%
# To filter data based on column name

#df[df['Category'] == ("Peace")]

# %%
# To select the first of the Category column
df.loc[12],['Category']
# Out:
# (Year                                                                                                         1902
#  Category                                                                                                  Physics
#  Prize                                                                             The Nobel Prize in Physics 1902
#  Motivation              "in recognition of the extraordinary service they rendered by their researches into th...
#  Prize Share                                                                                                01-Feb
#  Laureate ID                                                                                                     3
#  Laureate Type                                                                                          Individual
#  Full Name                                                                                           Pieter Zeeman
# ...
