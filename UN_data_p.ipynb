# %%
# Import required Libraries
import pandas as pd
import numpy as np
from pandas import Series
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as seabornInstance 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Dataset source: https://www.kaggle.com/eng0mohamed0nabil/population-by-country-2020

# %%
df = pd.read_csv('C:/Datasets-master/UN-Data/datasets_population_by_country_2020.csv')

# %%
df.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
# 2           United States          330610570        0.59 %     1937734
# 3               Indonesia          272931713        1.07 %     2898047
# 4                Pakistan          219992900        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
df.keys()
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
#y = df.set_index('Population (2020)')

# %%
g = sns.FacetGrid(df, col='Yearly Change')
g.map(plt.hist, 'Med. Age', bins=20)

# %%
y.plot(figsize=(15, 6))
plt.show()

# %%
print(df['Population (2020)'])
# Out:
# 0      1438207241
# 1      1377233523
# 2       330610570
# 3       272931713
# 4       219992900
#           ...
# 230          4991
# 231          3458
# 232          1624
# 233          1354
# 234           801
# Name: Population (2020), Length: 235, dtype: int64

# %%
from matplotlib import pyplot
pyplot.figure(1)
pyplot.subplot(211)
y.Population (2020).hist()
pyplot.subplot(212)
y.Population (2020).plot(kind='kde')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-f444dd5e797d> in <module>
#       2 pyplot.figure(1)
#       3 pyplot.subplot(211)
# ----> 4 y.Population (2020).hist()
#       5 pyplot.subplot(212)
#       6 y.Population (2020).plot(kind='kde')
#
# NameError: name 'y' is not defined

# %%
plt.figure(figsize=(9,6))
plt.tight_layout()
seabornInstance.distplot(df['Density (P/Km²)'])

# %%
sns.countplot(df['Urban Pop %'])

# %%
df['Migrants (net)'].astype(str)
#sns.factorplot('Sex',df,hue='Pclass')

df.plot(figsize=(15,5))

# %%
df['Land Area (Km²)'].plot(legend=True,figsize=(15,5))

# %%
df['Density (P/Km²)'].plot(legend=True,figsize=(10,4))

# %%
df['Net Change'].plot(legend=True,figsize=(10,4))

# %%
df['Yearly Change'].hist(bins=150)

# %%
df.plot(x='Country (or dependency)', y='Population (2020)', style='o')  
plt.title('Country vs Population')  
plt.xlabel('Country')  
plt.ylabel('Population')  
plt.show()

# %%
sns.distplot(df['Population (2020)'].dropna(),bins=50,color='purple')

# %%
'''
fig = sns.FacetGrid(df,hue='Yearly Change',aspect=4)
fig.map(sns.kdeplot,'Population (2020)',shade=True)

world_share = df['World Share'].max()

fig.set(xlim=(0,world_share))

fig.add_legend()
'''
# Out:
# "\nfig = sns.FacetGrid(df,hue='Yearly Change',aspect=4)\nfig.map(sns.kdeplot,'Population (2020)',shade=True)\n\nworld_share = df['World Share'].max()\n\nfig.set(xlim=(0,world_share))\n\nfig.add_legend()\n"

# %%
df['Yearly Change'].hist(bins=70)

# %%
# Visualising datset
sns.pairplot(df)
